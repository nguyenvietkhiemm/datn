# %% [markdown]
# # môi trường độc lập

# %%
from sympy.parsing.mathml import parse_mathml
from sympy import latex

mathml = """<math xmlns="http://www.w3.org/1998/Math/MathML"><mrow><mi>Q</mi><mo>=</mo><mi>c</mi><mi>m</mi><mo>(</mo><msub><mi>t</mi><mn>2</mn></msub><mo>-</mo><msub><mi>t</mi><mn>1</mn></msub><mo>)</mo><mo>+</mo><mi>&#x3BB;</mi><mi>m</mi><mo>=</mo><mn>96165</mn><mi>J</mi><mo>&#x2248;</mo><mn>96.17</mn><mi>kJ</mi></mrow></math>"""

expr = parse_mathml(mathml)
latex_formula = latex(expr)
print(latex_formula)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sympy.parsing.mathml import parse_mathml
#       2 from sympy import latex
#       4 mathml = """<math xmlns="http://www.w3.org/1998/Math/MathML"><mrow><mi>Q</mi><mo>=</mo><mi>c</mi><mi>m</mi><mo>(</mo><msub><mi>t</mi><mn>2</mn></msub><mo>-</mo><msub><mi>t</mi><mn>1</mn></msub><mo>)</mo><mo>+</mo><mi>&#x3BB;</mi><mi>m</mi><mo>=</mo><mn>96165</mn><mi>J</mi><mo>&#x2248;</mo><mn>96.17</mn><mi>kJ</mi></mrow></math>"""
#
# ModuleNotFoundError: No module named 'sympy.parsing.mathml'
